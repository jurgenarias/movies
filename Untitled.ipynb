# %%
df = pd.read_csv("movies.csv")

# %%
df
# Out:
#       imdb_title_id                                          title  \
# 0         tt0002130                                      L'Inferno
# 1         tt0003740                                        Cabiria
# 2         tt0004707                     Tillie's Punctured Romance
# 3         tt0004972                         Nascita di una nazione
# 4         tt0005078                                      The Cheat
# ...             ...                                            ...
# 20003     tt9831136                        The Banana Splits Movie
# 20004     tt9860728  Falling Inn Love - Ristrutturazione con amore
# 20005     tt9894470                                            VFW
# 20006     tt9898858                                Coffee & Kareem
# 20007     tt9900782                                         Kaithi
#
#                    original_title  year date_published  \
# 0                       L'Inferno  1911     1911-03-06
# ...

# %%
df = df[df['votes']>2000]

# %%
df.to_csv('movies.csv', index=False)

# %%
11.7

# %%
df.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
df[['imdb_title_id', 'title', 'original_title', 'year',
       'genre', 'director','actors', 'description', 'avg_vote', 'votes']]
# Out:
#       imdb_title_id                                          title  \
# 0         tt0002130                                      L'Inferno
# 1         tt0003740                                        Cabiria
# 2         tt0004707                     Tillie's Punctured Romance
# 3         tt0004972                         Nascita di una nazione
# 4         tt0005078                                      The Cheat
# ...             ...                                            ...
# 20003     tt9831136                        The Banana Splits Movie
# 20004     tt9860728  Falling Inn Love - Ristrutturazione con amore
# 20005     tt9894470                                            VFW
# 20006     tt9898858                                Coffee & Kareem
# 20007     tt9900782                                         Kaithi
#
#                    original_title  year                      genre  \
# 0                       L'Inferno  1911  Adventure, Drama, Fantasy
# ...

# %%
df.to_csv("movies2.csv")

# %%
df = pd.read_csv("out.csv")

# %%
df
# Out:
#       imdb_title_id                                          title  \
# 0         tt0002130                                      L'Inferno
# 1         tt0003740                                        Cabiria
# 2         tt0004707                     Tillie's Punctured Romance
# 3         tt0004972                         Nascita di una nazione
# 4         tt0005078                                      The Cheat
# ...             ...                                            ...
# 20003     tt9831136                        The Banana Splits Movie
# 20004     tt9860728  Falling Inn Love - Ristrutturazione con amore
# 20005     tt9894470                                            VFW
# 20006     tt9898858                                Coffee & Kareem
# 20007     tt9900782                                         Kaithi
#
#                    original_title  year date_published  \
# 0                       L'Inferno  1911     1911-03-06
# ...
